# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
import os
import json

# Set your Kaggle username and key
os.environ["KAGGLE_USERNAME"] = "rajan1999"
os.environ["KAGGLE_KEY"] = "3bea56d2e132aa1eb86e75bed0a60dfc"

# Write kaggle.json
kaggle_json = {
    "username": os.environ["KAGGLE_USERNAME"],
    "key": os.environ["KAGGLE_KEY"]
}

# Create Kaggle folder if it doesn't exist
os.makedirs("/root/.kaggle", exist_ok = True)

# Dump kaggle.json with credentials
with open("/root/.kaggle/kaggle.json", "w") as f:
    json.dump(kaggle_json, f)


os.chmod("/root/.kaggle/kaggle.json", 0o600)

# %%
# Downloads the dataset
dataset_url = "rajan1999/movies"   # Slug part of the kaggle's dataset url
# !kaggle datasets download -d {dataset_url} -p /content --unzip
# !ls /content
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rajan1999/movies
# License(s): CC0-1.0
# Downloading movies.zip to /content
# 100% 137M/137M [00:00<00:00, 1.40GB/s]
# 100% 137M/137M [00:00<00:00, 1.39GB/s]
# movies.csv  sample_data

# %%
movies = pd.read_csv("/content/movies.csv")

# %%
movies.sample(5)
# Out:
#             id                         title  \
# 596    1527482  Din Don 9 - Paesani spaesati
# 20780    44244    Camp Rock 2: The Final Jam
# 12031   549053                Last Christmas
# 20615   134597                The Collection
# 15800     1645                A Time to Kill
#
#                                              details_raw  \
# 596    {'adult': False, 'backdrop_path': '/aszRjyfmgf...
# 20780  {'adult': False, 'backdrop_path': '/tGgDjve3sY...
# 12031  {'adult': False, 'backdrop_path': '/qIjyBgsMDb...
# 20615  {'adult': False, 'backdrop_path': '/9wILyQxVRQ...
# 15800  {'adult': False, 'backdrop_path': '/bwLQCW6Lqm...
#
#                                              credits_raw  \
# 596    {'id': 1527482, 'cast': [{'adult': False, 'gen...
# 20780  {'id': 44244, 'cast': [{'adult': False, 'gende...
# 12031  {'id': 549053, 'cast': [{'adult': False, 'gend...
# 20615  {'id': 134597, 'cast': [{'adult': False, 'gend...
# 15800  {'id': 1645, 'cast': [{'adult': False, 'gender...
#
#                                                 keywords
# 596                      {'id': 1527482, 'keywords': []}
# 20780  {'id': 44244, 'keywords': [{'id': 5767, 'name'...
# 12031  {'id': 549053, 'keywords': [{'id': 212, 'name'...
# 20615  {'id': 134597, 'keywords': [{'id': 10685, 'nam...
# 15800  {'id': 1645, 'keywords': [{'id': 1589, 'name':...

# %%
movies.shape
# Out:
# (24050, 5)

# %% [markdown]
# ##**Data Cleaning**

# %%
import ast

# Convert these stringified columns back to Python dicts
movies["details_raw"] = movies["details_raw"].apply(ast.literal_eval)
movies["credits_raw"] = movies["credits_raw"].apply(ast.literal_eval)
movies["keywords"] = movies["keywords"].apply(ast.literal_eval)

# %%
Movies = pd.DataFrame({
    "id": movies["id"],
    "original_language": movies["details_raw"].apply(lambda x: x.get("original_language")),
    "title": movies["title"],
    "original_title": movies["details_raw"].apply(lambda x: x.get("original_title")),
    "overview": movies["details_raw"].apply(lambda x: x.get("overview")),
    "genres": movies["details_raw"].apply(lambda x: x.get("genres")),
    "keywords": movies["keywords"],
    "cast": movies["credits_raw"].apply(lambda x: x.get("cast")),
    "crew": movies["credits_raw"].apply(lambda x: x.get("crew"))
})

# %%
Movies.sample(5)
# Out:
#             id original_language                      title  \
# 18029    14367                en  Adventures in Babysitting
# 21203     9872                en                  Explorers
# 20650     9333                en          Last Man Standing
# 947     884003                te     Police Vari Heccharika
# 5498   1319969                en                     Sketch
#
#                   original_title  \
# 18029  Adventures in Babysitting
# 21203                  Explorers
# 20650          Last Man Standing
# 947          పోలీసు వరి హేచారికా
# 5498                      Sketch
#
#                                                 overview  \
# 18029  When plans with her boyfriend fall through, hi...
# 21203  Middle schooler Ben spends his free time watch...
# 20650  John Smith is a mysterious stranger who is dra...
# 947    Amid a wave of killings, officer Kanchana unco...
# 5498   When a young girl’s sketchbook falls into a st...
#
#                                                   genres  \
# 18029                     [{'id': 35, 'name': 'Comedy'}]
# 21203  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 20650  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 947    [{'id': 28, 'name': 'Action'}, {'id': 10749, '...
# 5498   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
#
#                                                 keywords  \
# 18029  {'id': 14367, 'keywords': [{'id': 2604, 'name'...
# 21203  {'id': 9872, 'keywords': [{'id': 1612, 'name':...
# 20650  {'id': 9333, 'keywords': [{'id': 947, 'name': ...
# 947                       {'id': 884003, 'keywords': []}
# 5498   {'id': 1319969, 'keywords': [{'id': 268132, 'n...
#
#                                                     cast  \
# 18029  [{'adult': False, 'gender': 1, 'id': 1951, 'kn...
# 21203  [{'adult': False, 'gender': 2, 'id': 569, 'kno...
# 20650  [{'adult': False, 'gender': 2, 'id': 62, 'know...
# 947    [{'adult': False, 'gender': 0, 'id': 5528290, ...
# 5498   [{'adult': False, 'gender': 2, 'id': 25147, 'k...
#
#                                                     crew
# 18029  [{'adult': False, 'gender': 1, 'id': 2162, 'kn...
# 21203  [{'adult': False, 'gender': 1, 'id': 16157, 'k...
# 20650  [{'adult': False, 'gender': 2, 'id': 1723, 'kn...
# 947    [{'adult': False, 'gender': 0, 'id': 2499482, ...
# 5498   [{'adult': False, 'gender': 2, 'id': 4266328, ...

# %%
# Function to extract genres, keywords, top 3 cast, and crew(director)
def convert_genres(x):

    L = []

    for i in x:
        L.append(i["name"])
    return L

def convert_keywords(x):

  L = []

  for i in x.get("keywords", []):
    L.append(i["name"])
  return L

def convert_top3(x):
  L = []

  counter = 0

  for i in x:
    if counter != 3:
      L.append(i["name"])
      counter += 1
    else:
      break
  return L

def fetch_director(x):

  L = []

  for i in x:
    if i["job"] == "Director":
      L.append(i["name"])
      break
  return L

# %%
# Extract genres, keywords, top 3 cast, and crew(director)
Movies["genres"] = Movies["genres"].apply(convert_genres)
Movies["keywords"] = Movies["keywords"].apply(convert_keywords)
Movies["cast"] = Movies["cast"].apply(convert_top3)
Movies["crew"] = Movies["crew"].apply(fetch_director)

# %%
Movies.sample(5)
# Out:
#            id original_language              title     original_title  \
# 10701  862551                en            Me Time            Me Time
# 21064    9896                en           Rat Race           Rat Race
# 20673  993784                en  Lisa Frankenstein  Lisa Frankenstein
# 21938   76640                en     The Last Stand     The Last Stand
# 10612  758336                en         Love Again         Love Again
#
#                                                 overview  \
# 10701  With his family away, a devoted stay-at-home d...
# 21064  In an ensemble film about easy money, greed, m...
# 20673  In 1989, a misunderstood teenager has a high s...
# 21938  Ray Owens is sheriff of the quiet US border to...
# 10612  Mira Ray, dealing with the loss of her fiancé,...
#
#                           genres  \
# 10701                   [Comedy]
# 21064        [Adventure, Comedy]
# 20673  [Horror, Comedy, Romance]
# 21938  [Action, Crime, Thriller]
# 10612   [Romance, Drama, Comedy]
#
#                                                 keywords  \
# 10701                   [stay-at-home dad, buddy comedy]
# 21064  [casino, road trip, millionaire, eccentric mil...
# 20673  [high school, cemetery, dark comedy, coming of...
# 21938  [small town, sheriff, prisoner, escape, hostag...
# 10612  [new york city, journalist, based on novel or ...
#
#                                                     cast              crew
# 10701           [Kevin Hart, Mark Wahlberg, Regina Hall]    [John Hamburg]
# 21064       [Rowan Atkinson, Lanei Chapman, John Cleese]    [Jerry Zucker]
# 20673      [Kathryn Newton, Cole Sprouse, Liza Soberano]  [Zelda Williams]
# 21938  [Arnold Schwarzenegger, Johnny Knoxville, Jaim...    [Kim Jee-woon]
# 10612  [Priyanka Chopra Jonas, Sam Heughan, Céline Dion]     [Jim Strouse]

# %%
# Any Missing Values?
Movies.isnull().sum()
# Out:
# id                   0
# original_language    0
# title                0
# original_title       0
# overview             0
# genres               0
# keywords             0
# cast                 0
# crew                 0
# dtype: int64

# %%
# Drop rows where overview, genres, keywords, cast, and crew are all empty
rows_to_drop = (
    (Movies["overview"].isna() | (Movies["overview"] == "")) &
    (Movies["genres"].apply(lambda x: len(x) == 0)) &
    (Movies["keywords"].apply(lambda x: len(x) == 0)) &
    (Movies["cast"].apply(lambda x: len(x) == 0)) &
    (Movies["crew"].apply(lambda x: len(x) == 0))
)

Movies[rows_to_drop] = Movies[rows_to_drop].replace("", np.nan)
Movies.dropna(inplace = True)

# %%
Movies.sample(5)
# Out:
#             id original_language               title  \
# 966    1336738                id            Tabayyun
# 4289    928334                pt       Julia's Lover
# 4320   1413643                es              Sin él
# 16762      138                en             Dracula
# 6176   1088514                es  The Room Next Door
#
#                  original_title  \
# 966                    Tabayyun
# 4289          O Amante de Júlia
# 4320                     Sin él
# 16762                   Dracula
# 6176   La habitación de al lado
#
#                                                 overview  \
# 966    Zalina and Arlo, two individuals from differen...
# 4289   Paralyzed from the waist down after an acciden...
# 4320
# 16762  British estate agent Renfield travels to Trans...
# 6176   Ingrid and Martha were close friends in their ...
#
#                           genres  \
# 966                      [Drama]
# 4289            [Romance, Drama]
# 4320   [Thriller, Horror, Drama]
# 16762                   [Horror]
# 6176                     [Drama]
#
#                                                 keywords  \
# 966    [muslim, based on novel or book, love, single ...
# 4289                                                  []
# 4320                                                  []
# 16762  [monster, based on novel or book, transylvania...
# 6176   [new york city, suicide, based on novel or boo...
#
#                                                  cast                     crew
# 966      [Titi Kamal, Ibrahim Risyad, Naysila Mirdad]         [Key Mangunsong]
# 4289       [Bianca Bin, Romulo Estrela, Sérgio Guizé]       [Vinicius Coimbra]
# 4320         [Aleida Torrent, David Marcé, Aida Flix]  [Emilio Martinez-Borso]
# 16762    [Bela Lugosi, Helen Chandler, David Manners]           [Tod Browning]
# 6176   [Julianne Moore, Tilda Swinton, John Turturro]        [Pedro Almodóvar]

# %%
# Any Duplicates?
Movies.duplicated(subset = "id").sum()
# Out:
# np.int64(6888)

# %%
# Drop Duplicates
Movies = Movies.drop_duplicates(subset = "id", keep = "first")

# %%
import requests
from time import sleep

API_KEY = "b8cd668a03ee6296f94919995b52d187"
BASE_URL = "https://api.themoviedb.org/3/movie/"

def has_english_translation(movie_id):
  """Check if the movie has an English translation on TMDB."""
  url = f"{BASE_URL}{movie_id}/translations?api_key={API_KEY}"
  try:
    resp = requests.get(url)
    data = resp.json()
    translations = data.get("translations", [])
    for t in translations:
      if t.get("iso_639_1") == "en":
        overview = t.get("data", {}).get("overview", "").strip()
        title = t.get("data", {}).get("title", "").strip()
        # Consider it translated if either title or overview has text
        if overview or title:
          return True
    return False
  except Exception as e:
    print(f"Error fetching {movie_id}: {e}")
    return None

Movies["has_en_translation"] = Movies["id"].apply(has_english_translation)

# Sleep between requests to avoid hitting rate limits
sleep(0.25)  # TMDB allows ~40 requests per 10 seconds per IP

# Filter those without English translation
no_english = Movies[
    (Movies["has_en_translation"] == False) &
    (Movies["original_language"] != "en")
    ]

print(f"Movies without English translations: {len(no_english)}")
# Out:
# Movies without English translations: 504

# %%
no_english.head(5)
# Out:
#           id original_language  \
# 173  1514770                ja
# 337  1529517                es
# 345  1497279                zh
# 400  1517911                nl
# 428  1526724                tl
#
#                                                  title  \
# 173  ドジで、タメ口で、すぐ不貞腐れるけど なんだかんだ性処理ご奉仕だけは絶対に手を抜かない 正直...
# 337                                 Reinas de la Noche
# 345                                           非人哉：限时玩家
# 400                        21 juli 2025: Belgian Party
# 428                                          Maalikaya
#
#                                         original_title  \
# 173  ドジで、タメ口で、すぐ不貞腐れるけど なんだかんだ性処理ご奉仕だけは絶対に手を抜かない 正直...
# 337                                 Reinas de la Noche
# 345                                           非人哉：限时玩家
# 400                        21 juli 2025: Belgian Party
# 428                                          Maalikaya
#
#                                               overview  \
# 173
# 337
# 345
# 400
# 428  Behind prison walls, inmate Kara explores her ...
#
#                          genres                        keywords  \
# 173                          []  [メイド, 主観, 中出し, 淫語, vr専用, ツンデレ]
# 337                    [Comedy]                              []
# 345  [Drama, Animation, Comedy]                              []
# 400                     [Music]                              []
# 428            [Drama, Romance]                      [softcore]
#
#                                                   cast               crew  \
# 173                                      [Arata Arina]            [ZAMPA]
# 337  [Catherine Siachoque, Cynthia Klitbo, Anna Cep...  [Yahayra Garrido]
# 345         [Yang Ning, Baomu Zhongyang, Su Shangqing]        [Aishan Yu]
# 400        [Francisco Schuster, Youssef Swatt’s, Colt]                 []
# 428                        [Jenn Rosa, Aliya Raymundo]  [Roman Perez Jr.]
#
#      has_en_translation
# 173               False
# 337               False
# 345               False
# 400               False
# 428               False

# %%
# !pip install deep_translator
# !pip install fasttext
! wget https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.ftz

# %%
import fasttext
import re
from deep_translator import GoogleTranslator

# Load language detection model
ft_model = fasttext.load_model("lid.176.ftz")

# Languages to detect
foreign_langs = {
    "zh", "ru", "ja", "ko", "ar", "he", "hi", "th", "ta", "te", "bn",
    "es", "it", "pl", "cs", "pt", "fr", "de", "tr", "nl", "sv", "da", "no"}

# Converts lists to text
def to_text(v):
  if isinstance(v, list):
    return " ".join(map(str, v))
  return str(v).strip() if v else ""

# Detect if the text looks foreign(by language or by script)
def is_foreign(text):
  text = to_text(text)
  if not text or len(text) < 3:
    return False

  # Detect non-ASCII characters
  if re.search(r"[^\x00-\x7F]", text):
    return True

  # Detect using FastText
  try:
    ft_lang = ft_model.predict(text, k = 1)[0][0].replace("__label__", "")
  except Exception:
    ft_lang = "unknown"

  # Return true if the language is in foreign set
  return ft_lang in foreign_langs

# Translate safely to English only when foreign
def translate(text):
  text = to_text(text)
  if not text or not is_foreign(text):
    return text  # Skip if empty or English
  try:
    return GoogleTranslator(source = "auto", target = "en").translate(text)
  except Exception:
    return text

# Apply to the DataFrame
def translate_df(df, columns):
  df = df.copy()
  for col in columns:
    print(f"Translating column: {col}")
    df[col] = df[col].apply(translate)
  return df

# %%
columns = ["title", "overview", "keywords"]
translated_movies = translate_df(no_english, columns)
# Out:
# Translating column: title
# Translating column: overview
# Translating column: keywords

# %%
no_english.head(5)
# Out:
#           id original_language  \
# 173  1514770                ja
# 337  1529517                es
# 345  1497279                zh
# 400  1517911                nl
# 428  1526724                tl
#
#                                                  title  \
# 173  ドジで、タメ口で、すぐ不貞腐れるけど なんだかんだ性処理ご奉仕だけは絶対に手を抜かない 正直...
# 337                                 Reinas de la Noche
# 345                                           非人哉：限时玩家
# 400                        21 juli 2025: Belgian Party
# 428                                          Maalikaya
#
#                                         original_title  \
# 173  ドジで、タメ口で、すぐ不貞腐れるけど なんだかんだ性処理ご奉仕だけは絶対に手を抜かない 正直...
# 337                                 Reinas de la Noche
# 345                                           非人哉：限时玩家
# 400                        21 juli 2025: Belgian Party
# 428                                          Maalikaya
#
#                                               overview  \
# 173
# 337
# 345
# 400
# 428  Behind prison walls, inmate Kara explores her ...
#
#                          genres                        keywords  \
# 173                          []  [メイド, 主観, 中出し, 淫語, vr専用, ツンデレ]
# 337                    [Comedy]                              []
# 345  [Drama, Animation, Comedy]                              []
# 400                     [Music]                              []
# 428            [Drama, Romance]                      [softcore]
#
#                                                   cast               crew  \
# 173                                      [Arata Arina]            [ZAMPA]
# 337  [Catherine Siachoque, Cynthia Klitbo, Anna Cep...  [Yahayra Garrido]
# 345         [Yang Ning, Baomu Zhongyang, Su Shangqing]        [Aishan Yu]
# 400        [Francisco Schuster, Youssef Swatt’s, Colt]                 []
# 428                        [Jenn Rosa, Aliya Raymundo]  [Roman Perez Jr.]
#
#      has_en_translation
# 173               False
# 337               False
# 345               False
# 400               False
# 428               False

# %%
translated_movies.head(5)
# Out:
#           id original_language  \
# 173  1514770                ja
# 337  1529517                es
# 345  1497279                zh
# 400  1517911                nl
# 428  1526724                tl
#
#                                                  title  \
# 173  She's clumsy, talkative, and easily becomes un...
# 337                                 Reinas de la Noche
# 345                      Inhumane: Limited Time Player
# 400                        21 juli 2025: Belgian Party
# 428                                          Maalikaya
#
#                                         original_title  \
# 173  ドジで、タメ口で、すぐ不貞腐れるけど なんだかんだ性処理ご奉仕だけは絶対に手を抜かない 正直...
# 337                                 Reinas de la Noche
# 345                                           非人哉：限时玩家
# 400                        21 juli 2025: Belgian Party
# 428                                          Maalikaya
#
#                                               overview  \
# 173
# 337
# 345
# 400
# 428  Behind prison walls, inmate Kara explores her ...
#
#                          genres  \
# 173                          []
# 337                    [Comedy]
# 345  [Drama, Animation, Comedy]
# 400                     [Music]
# 428            [Drama, Romance]
#
#                                           keywords  \
# 173  Maid POV Creampie Dirty Talk VR Only Tsundere
# 337
# 345
# 400
# 428                                       softcore
#
#                                                   cast               crew  \
# 173                                      [Arata Arina]            [ZAMPA]
# 337  [Catherine Siachoque, Cynthia Klitbo, Anna Cep...  [Yahayra Garrido]
# 345         [Yang Ning, Baomu Zhongyang, Su Shangqing]        [Aishan Yu]
# 400        [Francisco Schuster, Youssef Swatt’s, Colt]                 []
# 428                        [Jenn Rosa, Aliya Raymundo]  [Roman Perez Jr.]
#
#      has_en_translation
# 173               False
# 337               False
# 345               False
# 400               False
# 428               False

# %%
# Set "id" as index to align rows
Movies.set_index("id", inplace = True)
translated_movies.set_index("id", inplace = True)

# Update Movies with translations
Movies.update(translated_movies)

# Reset index if needed
Movies.reset_index(inplace = True)

# %%
Movies.sample(5)
# Out:
#             id original_language           title original_title  \
# 15753    41479                en     The Joneses    The Joneses
# 8791    560527                ko  The Dude in Me         내안의 그놈
# 10980   182560                en     Dark Places    Dark Places
# 15222   582913                en        The Room       The Room
# 1566   1447771                en     The Big Sea    The Big Sea
#
#                                                 overview  \
# 15753  A seemingly perfect family moves into a suburb...
# 8791   Dong-hyun is a high school student. One day, h...
# 10980  A woman who survived the brutal killing of her...
# 15222  Kate and Matt discover that a part of their ho...
# 1566   Surfing is killing it. This $10 billion global...
#
#                                           genres  \
# 15753                            [Comedy, Drama]
# 8791                   [Fantasy, Comedy, Action]
# 10980          [Thriller, Mystery, Drama, Crime]
# 15222  [Horror, Drama, Mystery, Science Fiction]
# 1566                                          []
#
#                                                 keywords  \
# 15753                [materialism, duringcreditsstinger]
# 8791                                         [body-swap]
# 10980  [prison, sibling relationship, based on novel ...
# 15222  [wish, miscarriage, family, reality vs fantasy...
# 1566                                                  []
#
#                                                     cast  \
# 15753          [David Duchovny, Demi Moore, Amber Heard]
# 8791        [Jung Jin-young, Park Sung-woong, Ra Mi-ran]
# 10980  [Charlize Theron, Nicholas Hoult, Chloë Grace ...
# 15222  [Olga Kurylenko, Kevin Janssens, Francis Chapman]
# 1566                                                  []
#
#                           crew  has_en_translation
# 15753          [Derrick Borte]                True
# 8791            [Kang Hyo-jin]                True
# 10980  [Gilles Paquet-Brenner]                True
# 15222     [Christian Volckman]                True
# 1566            [Lewis Arnold]                True

# %%
# Converting Overview from string to list
Movies["overview"] = Movies["overview"].apply(lambda x: x.split())

# %%
# Remove spaces between words(genres, keywords, cast, crew)
Movies["genres"] = Movies["genres"].apply(lambda x: [i.replace(" ", "") for i in x])
Movies["keywords"] = Movies["keywords"].apply(lambda x: [i.replace(" ", "") for i in x])
Movies["cast"] = Movies["cast"].apply(lambda x: [i.replace(" ", "") for i in x])
Movies["crew"] = Movies["crew"].apply(lambda x: [i.replace(" ", "") for i in x])

# %%
# Create a new column tags, a combination of overview, genres, keywords, cast, and crew
Movies["tags"] = Movies["overview"] + Movies["genres"] + Movies["keywords"] + Movies["cast"] + Movies["crew"]

# %%
# Convert the tags column to a string
Movies["tags"] = Movies["tags"].apply(lambda x: " ".join(x))

# %%
movies_df = Movies[["id", "title", "tags"]].copy()

# %%
movies_df.sample(10)
# Out:
#             id                                              title  \
# 16099    10093                                         The Return
# 198    1359607  Miss Kobayashi's Dragon Maid: A Lonely Dragon ...
# 1293   1485959                                    Ikigake no sora
# 3765   1480749                                       Time's Arrow
# 14320    11617                                         Rio Grande
# 5069    206647                                            Spectre
# 688    1486092                     Gandhi Was Silent on Saturdays
# 16377   471507                                          Destroyer
# 8463    296989                          The Other Side of The SEX
# 13756   369523                                           The Tale
#
#                                                     tags
# 16099  Joanna Mills has a successful career but feels...
# 198    Miss Kobayashi, Tohru, Kanna, and Iruru's peac...
# 1293   Drama TakahiroMiura MisakiHattori Nahana Shini...
# 3765   A tentative teenager, entering her formative y...
# 14320  Lt. Col. Kirby Yorke is posted on the Texas fr...
# 5069   A cryptic message from Bond’s past sends him o...
# 688    The life of 16-year-old Mot is thrown into dis...
# 16377  When Erin Bell was a young cop, she was given ...
# 8463   A documentary that shines a spotlight on the u...
# 13756  An investigation into one woman’s memory as sh...

# %% [markdown]
# ##**Data Preprocessing**

# %%
import re

# %%
# Basic cleaning: remove extra spaces, line breaks, trailing spaces
def clean_text(text):
  text = re.sub(r"\s+", " ", text)   # replace multiple spaces with one
  text = text.strip()                # remove leading/trailing spaces
  return text

# %%
# Apply cleaning to your movie tags column
movies_df["tags"] = movies_df["tags"].apply(clean_text)

# %% [markdown]
# ##**Modeling**

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.1-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.13.1-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 23.2 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.1

# %%
from sentence_transformers import SentenceTransformer
import faiss

# %%
# Load a small, fast embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Convert all movie tags into 384-dimensional embeddings (vectors)
embeddings = model.encode(
    movies_df["tags"].tolist(),
    show_progress_bar = True,
    convert_to_numpy = True
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/536 [00:00<?, ?it/s]

# %%
# Get the size of each embedding vector
d = embeddings.shape[1]

# Create a FAISS index that uses L2 distance for similarity search
index = faiss.IndexFlatL2(d)

# Add all movie embeddings to the FAISS index
index.add(embeddings)

# %%
# Recommend k similar movies using FAISS search
def recommend(movie, k = 5):
    movie_index = movies_df[movies_df["title"] == movie].index[0]

    # Get the embedding of the selected movie
    query_vec = embeddings[movie_index].reshape(1,-1)

    # Search FAISS for the k nearest neighbours
    distances, indices = index.search(query_vec, k + 1)   # +1 because the closest movie to a movie is itself

    # Skip the first result because it's itself
    recommended_indices = indices[0][1:]

    # Print the recommended movie titles
    for idx in recommended_indices:
        print(movies_df.iloc[idx].title)

# %%
recommend("One Piece Film: GOLD")
# Out:
# One Piece Film: Strong World
# One Piece "3D2Y": Overcome Ace's Death! Luffy's Vow to his Friends
# One Piece: The Movie
# One Piece Film: Z
# One Piece: Heart of Gold

# %%
import pickle

# %%
# Save the movies dataframe as a dict
movies_dict = movies_df.to_dict()

pickle.dump(movies_dict, open("movies_dict.pkl", "wb"))

# %%
# Save embeddings
with open("embeddings.pkl", "wb") as f:
    pickle.dump(embeddings, f)

# %%
# Save FAISS index
faiss.write_index(index, "faiss_index.bin")
